# %% [markdown]
# # EvebodyDanceNow Inference
# In this colab notebook, we will show how to make dance video with your pretrained model.
#
# Enjoy!

# %% [markdown]
# # Preparations
# Before start, make sure that you choose
# * Hardware Accelerator = GPU
#
# in the **Runtime** menu -> **Change runtime type**

# %%
# !nvidia-smi
# Out:
# Wed Apr 28 13:36:23 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %%capture
# !pip install gdown
# !pip install dominate

# %%
# %%capture
# !git clone https://github.com/OrionChocoPie/EverybodyDanceNow.git

# %%
# %%capture
# !gdown https://drive.google.com/uc?id=1OlqoZumoeWyWmoGGrrf3AyHU7Rr1O55P
# !tar -xvf /content/EverybodyDanceNow/subject1.tar

# !gdown https://drive.google.com/uc?id=1Fi0U27qA1RS2T5kCI0E4eg3nVdmTKNkj
# !tar -xvf subject2.tar

# %%
import os

os.chdir('/content/EverybodyDanceNow')

# %%
dance_path = '/content/drive/MyDrive/dancegan/bruno_mars/avesmooth/'
checkpoints_dir = '/content/drive/MyDrive/dancegan/dancegan_checkpoints/'
load_pretrain = '/content/drive/MyDrive/dancegan/dancegan_checkpoints/danceGAN_face/'

version = 'danceGAN_local' # 'danceGAN_face' 'danceGAN_global'

results_dir = '/content/drive/MyDrive/dancegan/test_results/transfer/'

# %% [markdown]
# # Inference

# %%
# !python /content/EverybodyDanceNow/test_fullts.py \
    --name '{version}' \
    --dataroot '{dance_path}' \
    --checkpoints_dir '{checkpoints_dir}' \
    --load_pretrain '{load_pretrain}' \
    --results_dir '{results_dir}' \
    --loadSize 1024 \
    --netG local \
    --ngf 32 \
    --resize_or_crop none \
    --no_instance \
    --how_many 10000 \
    --label_nc 6 \
# Out:
# ------------ Options -------------
# aspect_ratio: 1.0
# batchSize: 1
# checkpoints_dir: /content/drive/MyDrive/dancegan/dancegan_checkpoints/
# cluster_path: features_clustered_010.npy
# dataroot: /content/drive/MyDrive/dancegan/bruno_mars/avesmooth/
# display_winsize: 512
# faceGtype: unet
# face_discrim: False
# face_generator: False
# feat_num: 3
# fineSize: 512
# gestures: False
# gpu_ids: [0]
# how_many: 10000
# instance_feat: False
# isTrain: False
# label_feat: False
# label_nc: 6
# lambda_feat: 10.0
# loadSize: 1024
# load_features: False
# load_pretrain: /content/drive/MyDrive/dancegan/dancegan_checkpoints/danceGAN_face/
# max_dataset_size: inf
# nThreads: 2
# n_blocks_global: 9
# n_blocks_local: 3
# n_clusters: 10
# n_downsample_E: 4
# n_downsample_global: 4
# n_layers_D: 3
# n_layers_D_face: 3
# n_local_enhancers: 1
# name: danceGAN_local
# ndf: 64
# nef: 16
# netG: local
# ngf: 32
# niter_fix_global: 0
# niter_fix_main: 0
# no_flip: False
# no_ganFeat_loss: False
# ...

# %%
# !rm '{path_video}'ffmpeg.mp4
# !ffmpeg -framerate 30 -pattern_type glob -i '{results_dir}''{version}'/test_latest/images/'*.png' \
  -c:v libx264 -pix_fmt yuv420p '{results_dir}'ffmpeg.mp4
# Out:
# rm: cannot remove '{path_video}ffmpeg.mp4': No such file or directory
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# ...
